# %%
import pandas as pd

# %%
df = pd.read_csv('data/datos_delitos.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('data/datos_delitos.csv')
#
# File ~/pandas_primeros_pasos_cloeesenses/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/pandas_primeros_pasos_cloeesenses/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/pandas_primeros_pasos_cloeesenses/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/pandas_primeros_pasos_cloeesenses/.venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/pandas_primeros_pasos_cloeesenses/.venv/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf1 in position 1: invalid continuation byte

# %% [markdown]
# # Errorde Encoding
#
# Aquí tenemos un error muy común que suele ocurrir cuando un archivo se guarda en una computadora con cierto "encoding".
#
# Un encoding, a grandes rasgos, es una tabla que relaciona un número con un carácter. Por ejemplo, en la tabla ASCII, el número 65 corresponde a la letra "A".
#
# Si el archivo que estamos leyendo fue guardado con un encoding distinto al que pandas espera, nos arrojará un error.
#
# Para solucionar esto, podemos utilizar el parámetro encoding de la función pd.read_csv() y especificar el encoding correcto.
#
# ¿Pero cómo sabemos con qué encoding cuenta el archivo?
#
# La realidad es que la gran mayoría de los archivos los encontrarán en encoding utf-8 y Pandas no va a dar ningún error. Aquí estamos teniendo este problema porque la computadora que utilizan para generar este archivo uso un encoding diferente a utf-8.
#
# En México, por lo general, si un archivo no está en utf-8, lo más seguro es que esté en ISO-8859-1 o latin1.
#
# Intentemos cargar el archivo especificando el encoding ISO-8859-1

# %%
df = pd.read_csv('data/datos_delitos.csv', encoding='ISO-8859-1')
df.head()
# Out:
#     Año  Clave_Ent         Entidad            Bien jurídico afectado  \
# 0  2015          1  Aguascalientes  La vida y la Integridad corporal
# 1  2015          1  Aguascalientes  La vida y la Integridad corporal
# 2  2015          1  Aguascalientes  La vida y la Integridad corporal
# 3  2015          1  Aguascalientes  La vida y la Integridad corporal
# 4  2015          1  Aguascalientes  La vida y la Integridad corporal
#
#   Tipo de delito  Subtipo de delito          Modalidad  Enero  Febrero  Marzo  \
# 0      Homicidio   Homicidio doloso  Con arma de fuego      3        0      2
# 1      Homicidio   Homicidio doloso    Con arma blanca      1        1      0
# 2      Homicidio   Homicidio doloso  Con otro elemento      0        0      2
# 3      Homicidio   Homicidio doloso    No especificado      2        0      0
# 4      Homicidio  Homicidio culposo  Con arma de fuego      0        0      0
#
#    Abril  Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  \
# 0      1     1      1      2       1           2        2          2
# 1      0     0      1      0       1           0        0          0
# 2      2     3      2      0       1           2        0          0
# 3      1     0      0      0       0           0        0          0
# 4      0     1      0      0       0           0        0          0
#
#    Diciembre
# 0        1.0
# 1        1.0
# 2        0.0
# 3        0.0
# 4        0.0

# %% [markdown]
# # ¿Existe alguna forma de verificar el encoding de un archivo sin tener que estar adivinando?

# %%
import chardet

def detect_encoding_safe(file_path, n_bytes=100_000):
    with open(file_path, 'rb') as f:
        rawdata = f.read(n_bytes)
    return chardet.detect(rawdata)

file_path = './data/datos_delitos.csv'
encoding_info = detect_encoding_safe(file_path)

encoding_info
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# - Le pedi a ChatGPT que modificara el codigo del libro, ya que eran tantos datos que se trababa al querer leer todos. Este codigo solo lee 100 kb
#
# - Tambien tuve que instalar la libreria chardet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34496 entries, 0 to 34495
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Año                     34496 non-null  int64
#  1   Clave_Ent               34496 non-null  int64
#  2   Entidad                 34496 non-null  object
#  3   Bien jurídico afectado  34496 non-null  object
#  4   Tipo de delito          34496 non-null  object
#  5   Subtipo de delito       34496 non-null  object
#  6   Modalidad               34496 non-null  object
#  7   Enero                   34496 non-null  int64
#  8   Febrero                 34496 non-null  int64
#  9   Marzo                   34496 non-null  int64
#  10  Abril                   34496 non-null  int64
#  11  Mayo                    34496 non-null  int64
#  12  Junio                   34496 non-null  int64
#  13  Julio                   34496 non-null  int64
#  14  Agosto                  34496 non-null  int64
#  15  Septiembre              34496 non-null  int64
#  16  Octubre                 34496 non-null  int64
#  17  Noviembre               34496 non-null  int64
#  18  Diciembre               31360 non-null  float64
# dtypes: float64(1), int64(13), object(5)
# memory usage: 5.0+ MB

# %% [markdown]
# Bien. Están muy bien los datos. Sin embargo, tenemos un problema con el que es muy común encontrarnos.
#
# Resulta que el formato en el que está el archivo es fácil entender por seres humanos:

# %% [markdown]
# | Año      | Entidad  | Enero    | Febrero  | Mes X    |
# |----------|----------|----------|----------|----------|
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |
# |   ...    |   ...    |   ...    |   ...    |   ...    |

# %% [markdown]
# Vemos que tenemos los meses como encabezados. Es decir, el archivo está tratando cada mes como si fuera una variable.
#
# Nosotros como científicos de datos estamos más interesados en conjuntos de datos que no estén en este formato de "resumen" o "tabla dinámica". Para nosotros, lo ideal sería que cada mes fuera simplemente una observación más en nuestro conjunto de datos. Es decir, queremos transformar la tabla de arriba en:

# %% [markdown]
# | Año      | Entidad  | Mes        |
# |----------|----------|------------|
# |   ...    |   ...    |   Enero    |
# |   ...    |   ...    |   Febrero  |
# |   ...    |   ...    |   Marzo    |
# |   ...    |   ...    |   Abril    |
# |   ...    |   ...    |   Mes X    |

# %% [markdown]
# # Hora de limpiar datos
#
# Haremos las siguientes “limpiezas”:
# - Transformar los nombres de las columnas para que no tengan caracteres especiales y estén siempre en minúsculas
# - Convertir el dataset a un formato de datos "largo"

# %% [markdown]
# # Limpiar nombres de columnas
#
# Recordemos que df.columns nos regresa una especie de lista que contiene los nombres de las columnas:

# %%
for col in df.columns:
    print(col)
# Out:
# Año
# Clave_Ent
# Entidad
# Bien jurídico afectado
# Tipo de delito
# Subtipo de delito
# Modalidad
# Enero
# Febrero
# Marzo
# Abril
# Mayo
# Junio
# Julio
# Agosto
# Septiembre
# Octubre
# Noviembre
# Diciembre

# %% [markdown]
# # DEF para limiar columnas

# %%
def limpiar_columnas(df):
    columnas_limpias = []
    for col in df.columns:
        # convertir a minusculas, reemplazar espacios por guiones bajos y eliminar caracteres especiales
        col = col.lower().replace(" ", "_").replace("ñ", "ni").replace(".", "").replace("á", "a").replace("é", "e").replace("í","i").replace("ó", "o").replace("ú", "u")
        columnas_limpias.append(col)
    
    df.columns = columnas_limpias
    
    return df

# %% [markdown]
# - Esto solamente se puede hacer si la nueva lista columnas_limpias tiene la misma cantidad de elementos que df.columns.

# %%
df = limpiar_columnas(df) #Aqui uso mi funcion guardandola sobre mi df origininal
df.head(3)
# Out:
#    anio  clave_ent         entidad            bien_juridico_afectado  \
# 0  2015          1  Aguascalientes  La vida y la Integridad corporal
# 1  2015          1  Aguascalientes  La vida y la Integridad corporal
# 2  2015          1  Aguascalientes  La vida y la Integridad corporal
#
#   tipo_de_delito subtipo_de_delito          modalidad  enero  febrero  marzo  \
# 0      Homicidio  Homicidio doloso  Con arma de fuego      3        0      2
# 1      Homicidio  Homicidio doloso    Con arma blanca      1        1      0
# 2      Homicidio  Homicidio doloso  Con otro elemento      0        0      2
#
#    abril  mayo  junio  julio  agosto  septiembre  octubre  noviembre  \
# 0      1     1      1      2       1           2        2          2
# 1      0     0      1      0       1           0        0          0
# 2      2     3      2      0       1           2        0          0
#
#    diciembre
# 0        1.0
# 1        1.0
# 2        0.0

# %% [markdown]
# # QUITAR COLUMNAS

# %%
df = df[['anio', 'clave_ent', 'entidad', 'tipo_de_delito', 'subtipo_de_delito', 'modalidad','enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre']]
df.head(2)
# Out:
#    anio  clave_ent         entidad tipo_de_delito subtipo_de_delito  \
# 0  2015          1  Aguascalientes      Homicidio  Homicidio doloso
# 1  2015          1  Aguascalientes      Homicidio  Homicidio doloso
#
#            modalidad  enero  febrero  marzo  abril  mayo  junio  julio  \
# 0  Con arma de fuego      3        0      2      1     1      1      2
# 1    Con arma blanca      1        1      0      0     0      1      0
#
#    agosto  septiembre  octubre  noviembre  diciembre
# 0       1           2        2          2        1.0
# 1       1           0        0          0        1.0

# %% [markdown]
# # Formato largo de datos
#
# Ahora, usaremos el método melt para convertir las columnas a observaciones.
#
# Queremos convervar las coumnas:
#
# - anio
# - clave_ent
# - entidad
# - tipo_de_delito
# - subtipo_de_delito
# - modalidad
#
# El resto de las columnas las vamos a juntar en una nueva columna llamada "nombre_mes" y sus valores los vamos a sumar en otra llamada "frecuencia".

# %%
print("Shape: ", df.shape)
# Out:
# Shape:  (34496, 18)

# %% [markdown]
# # Ahora creemos un nuevo dataframe usando melt

# %%
datos_long = df.melt(
  id_vars=['anio', 'clave_ent', 'entidad','tipo_de_delito', 'subtipo_de_delito', 'modalidad'],
  var_name='nombre_mes',
  value_name='frecuencia'
)

# %% [markdown]
# Y veamos cómo cambia el Shape

# %%
print("Shape: ", datos_long.shape)
# Out:
# Shape:  (413952, 8)

# %%
datos_long.head(5)
# Out:
#    anio  clave_ent         entidad tipo_de_delito  subtipo_de_delito  \
# 0  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 1  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 2  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 3  2015          1  Aguascalientes      Homicidio   Homicidio doloso
# 4  2015          1  Aguascalientes      Homicidio  Homicidio culposo
#
#            modalidad nombre_mes  frecuencia
# 0  Con arma de fuego      enero         3.0
# 1    Con arma blanca      enero         1.0
# 2  Con otro elemento      enero         0.0
# 3    No especificado      enero         2.0
# 4  Con arma de fuego      enero         0.0

# %%
datos_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413952 entries, 0 to 413951
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   anio               413952 non-null  int64
#  1   clave_ent          413952 non-null  int64
#  2   entidad            413952 non-null  object
#  3   tipo_de_delito     413952 non-null  object
#  4   subtipo_de_delito  413952 non-null  object
#  5   modalidad          413952 non-null  object
#  6   nombre_mes         413952 non-null  object
#  7   frecuencia         410816 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 25.3+ MB

# %% [markdown]
# Supongamos que para este análisis, no nos importan los niveles subtipo de delito y modalidad. O sea, no queremos tener la distinción entre homicidios dolosos y culposos (claro está que estos son muy diferentes, pero ignoremos esta diferencia con el fin de simplificar este ejercicio).
#
# Vamos a agrupar nuestro dataframe por anio, clave_ent, entidad, tipo_de_delito y nombre_mes. Esto hará que todos los tipos de homicidios se sumen al tipo "homicidio" o todos los tipos de robo de vehículo (con o sin violencia) se sumen a "robo de vehículo".

# %%
datos_long = datos_long.groupby(['anio', 'clave_ent', 'entidad', 'tipo_de_delito', 'nombre_mes'])['frecuencia'].sum().reset_index()
datos_long[datos_long.tipo_de_delito == 'Robo'].sample(15)
# Out:
#         anio  clave_ent               entidad tipo_de_delito  nombre_mes  \
# 38312   2017         16   Michoacán de Ocampo           Robo        mayo
# 40709   2017         21                Puebla           Robo       julio
# 108394  2022          2       Baja California           Robo     octubre
# 154945  2025          3   Baja California Sur           Robo      agosto
# 41191   2017         22             Querétaro           Robo       marzo
# 66155   2019         10               Durango           Robo  septiembre
# 66634   2019         11            Guanajuato           Robo     octubre
# 160705  2025         15                México           Robo      agosto
# 122315  2022         31               Yucatán           Robo  septiembre
# 8075    2015         17               Morelos           Robo  septiembre
# 107915  2022          1        Aguascalientes           Robo  septiembre
# 155911  2025          5  Coahuila de Zaragoza           Robo       marzo
# 86794   2020         21                Puebla           Robo     octubre
# 64714   2019          7               Chiapas           Robo     octubre
# 28707   2016         28            Tamaulipas           Robo       enero
#
#         frecuencia
# 38312       1525.0
# 40709       2531.0
# 108394      2790.0
# 154945       459.0
# 41191       2259.0
# 66155        871.0
# 66634       3684.0
# 160705      7769.0
# 122315        49.0
# 8075        1765.0
# 107915       933.0
# 155911       449.0
# 86794       2257.0
# 64714        454.0
# 28707       1293.0

# %% [markdown]
# Lo acabamos de hacer es “eliminar” las dimensiones de subtipo de delito y modalidad.

# %% [markdown]
# Mostremos todos los estados y su respectiva clave

# %%
datos_long[['clave_ent', 'entidad']].drop_duplicates().sort_values('entidad')
# Out:
#        clave_ent                          entidad
# 0              1                   Aguascalientes
# 480            2                  Baja California
# 960            3              Baja California Sur
# 1440           4                         Campeche
# 2880           7                          Chiapas
# 3360           8                        Chihuahua
# 3840           9                 Ciudad de México
# 1920           5             Coahuila de Zaragoza
# 2400           6                           Colima
# 4320          10                          Durango
# 4800          11                       Guanajuato
# 5280          12                         Guerrero
# 5760          13                          Hidalgo
# 6240          14                          Jalisco
# 7200          16              Michoacán de Ocampo
# 7680          17                          Morelos
# 6720          15                           México
# 8160          18                          Nayarit
# 8640          19                       Nuevo León
# 9120          20                           Oaxaca
# 9600          21                           Puebla
# 10080         22                        Querétaro
# 10560         23                     Quintana Roo
# 11040         24                  San Luis Potosí
# 11520         25                          Sinaloa
# 12000         26                           Sonora
# 12480         27                          Tabasco
# 12960         28                       Tamaulipas
# 13440         29                         Tlaxcala
# 13920         30  Veracruz de Ignacio de la Llave
# 14400         31                          Yucatán
# 14880         32                        Zacatecas

# %% [markdown]
# Ahora Veamos todos los datos de delitos de una entidad en específico. Por ejemplo, Nuevo león

# %%
datos_long[datos_long['clave_ent'] == 19].sample(15)
# Out:
#         anio  clave_ent     entidad  \
# 24130   2016         19  Nuevo León
# 162639  2025         19  Nuevo León
# 54787   2018         19  Nuevo León
# 146926  2024         19  Nuevo León
# 116507  2022         19  Nuevo León
# 39539   2017         19  Nuevo León
# 116417  2022         19  Nuevo León
# 100850  2021         19  Nuevo León
# 162411  2025         19  Nuevo León
# 101063  2021         19  Nuevo León
# 85514   2020         19  Nuevo León
# 100925  2021         19  Nuevo León
# 70401   2019         19  Nuevo León
# 85839   2020         19  Nuevo León
# 8840    2015         19  Nuevo León
#
#                                            tipo_de_delito  nombre_mes  \
# 24130                                             Despojo     octubre
# 162639                                          Secuestro       enero
# 54787                                            Amenazas       marzo
# 146926                                       Acoso sexual     octubre
# 116507  Otros delitos que atentan contra la libertad p...  septiembre
# 39539                                            Falsedad  septiembre
# 116417  Incumplimiento de obligaciones de asistencia f...       julio
# 100850                             Allanamiento de morada   diciembre
# 162411                                           Falsedad       enero
# 101063  Incumplimiento de obligaciones de asistencia f...  septiembre
# 85514                            Contra el medio ambiente   diciembre
# 100925                                            Despojo       julio
# 70401                    Otros delitos contra la sociedad   noviembre
# 85839                                           Secuestro       enero
# 8840                                          Feminicidio        mayo
#
#         frecuencia
# 24130         71.0
# 162639         3.0
# 54787        374.0
# 146926        77.0
# 116507       234.0
# 39539         23.0
# 116417        44.0
# 100850        50.0
# 162411        19.0
# 101063        51.0
# 85514          0.0
# 100925       122.0
# 70401          1.0
# 85839          2.0
# 8840           0.0

# %%
datos_long[(datos_long['clave_ent'] == 30) & (datos_long['tipo_de_delito'] == 'Feminicidio')].sample(30)
# Out:
#         anio  clave_ent                          entidad tipo_de_delito  \
# 90921   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 90918   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 29477   2016         30  Veracruz de Ignacio de la Llave    Feminicidio
# 90919   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 90914   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 137002  2023         30  Veracruz de Ignacio de la Llave    Feminicidio
# 106279  2021         30  Veracruz de Ignacio de la Llave    Feminicidio
# 152357  2024         30  Veracruz de Ignacio de la Llave    Feminicidio
# 14112   2015         30  Veracruz de Ignacio de la Llave    Feminicidio
# 152360  2024         30  Veracruz de Ignacio de la Llave    Feminicidio
# 152359  2024         30  Veracruz de Ignacio de la Llave    Feminicidio
# 137003  2023         30  Veracruz de Ignacio de la Llave    Feminicidio
# 60193   2018         30  Veracruz de Ignacio de la Llave    Feminicidio
# 152354  2024         30  Veracruz de Ignacio de la Llave    Feminicidio
# 90922   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 14119   2015         30  Veracruz de Ignacio de la Llave    Feminicidio
# 60200   2018         30  Veracruz de Ignacio de la Llave    Feminicidio
# 60198   2018         30  Veracruz de Ignacio de la Llave    Feminicidio
# 90916   2020         30  Veracruz de Ignacio de la Llave    Feminicidio
# 60201   2018         30  Veracruz de Ignacio de la Llave    Feminicidio
# 121637  2022         30  Veracruz de Ignacio de la Llave    Feminicidio
# 44842   2017         30  Veracruz de Ignacio de la Llave    Feminicidio
# 106275  2021         30  Veracruz de Ignacio de la Llave    Feminicidio
# 44833   2017         30  Veracruz de Ignacio de la Llave    Feminicidio
# 14117   2015         30  Veracruz de Ignacio de la Llave    Feminicidio
# 75552   2019         30  Veracruz de Ignacio de la Llave    Feminicidio
# 14115   2015         30  Veracruz de Ignacio de la Llave    Feminicidio
# 60192   2018         30  Veracruz de Ignacio de la Llave    Feminicidio
# 75557   2019         30  Veracruz de Ignacio de la Llave    Feminicidio
# 106277  2021         30  Veracruz de Ignacio de la Llave    Feminicidio
#
#         nombre_mes  frecuencia
# 90921    noviembre         6.0
# 90918        junio         8.0
# 29477        julio         4.0
# 90919        marzo         7.0
# 90914    diciembre         5.0
# 137002     octubre         1.0
# 106279       marzo         7.0
# 152357       julio         4.0
# 14112        abril         4.0
# 152360        mayo         9.0
# 152359       marzo         3.0
# 137003  septiembre         2.0
# 60193       agosto        10.0
# 152354   diciembre         2.0
# 90922      octubre         4.0
# 14119        marzo         2.0
# 60200         mayo         8.0
# 60198        junio        13.0
# 90916      febrero        10.0
# 60201    noviembre         3.0
# 121637       julio         3.0
# 44842      octubre         8.0
# 106275       enero         6.0
# 44833       agosto        12.0
# 14117        julio         4.0
# 75552        abril        10.0
# 14115        enero         3.0
# 60192        abril        16.0
# 75557        julio         9.0
# 106277       julio         3.0

# %% [markdown]
# # Valores de fechas
#
# Finalmente, queremos tener una columna "fecha". Actualmente tenemos el año y el nombre del mes, pero no tenemos como tal una columna que tenga un tipo de dato fecha. Eso hace que filtrar por fecha sea complicado.
#
# Por ejemplo, si queremos conocer todos los homicidios de Oaxaca en enero 2024, haríamos lo siguiente:

# %%
datos_long[
    (datos_long['clave_ent'] == 20) &
    (datos_long['tipo_de_delito'] == 'Homicidio') &
    (datos_long['anio'] == 2024) &
    (datos_long['nombre_mes'] == 'enero') 
]
# Out:
#         anio  clave_ent entidad tipo_de_delito nombre_mes  frecuencia
# 147579  2024         20  Oaxaca      Homicidio      enero       154.0

# %% [markdown]
# Veremos que Pandas hace muy sencillo el manejo de fechas.
#
# Primero que nada, creemos nuea nueva columna. La forma más fácil de crear una nueva columna en un dataframe de pandas es de la misma forma que agregamos nuevos valores a un diccionario:

# %%
df["nueva_columna"] = "valor"

# %% [markdown]
# Esta línea anterior, crearía una nueva columna llamada nueva_columna, y se le asignaría el string “valor” a todos los valores de esta nueva serie.
#
# Haremos algo un poco diferente en este caso:

# %%
# Diccionario de ayuda para convertir
meses = {
    "enero": 1,
    "febrero": 2,
    "marzo": 3,
    "abril": 4,
    "mayo": 5,
    "junio": 6,
    "julio": 7,
    "agosto": 8,
    "septiembre": 9,
    "octubre": 10,
    "noviembre": 11,
    "diciembre": 12
}

datos_long['mes'] = datos_long['nombre_mes'].map(meses)
datos_long.sample(5)
# Out:
#         anio  clave_ent          entidad      tipo_de_delito nombre_mes  \
# 26664   2016         24  San Luis Potosí            Lesiones      abril
# 149972  2024         25          Sinaloa              Fraude       mayo
# 36631   2017         13          Hidalgo   Evasión de presos      marzo
# 101272  2021         19       Nuevo León  Violencia familiar    febrero
# 157028  2025          8        Chihuahua            Amenazas       mayo
#
#         frecuencia  mes
# 26664        330.0    4
# 149972       101.0    5
# 36631          0.0    3
# 101272      1257.0    2
# 157028       281.0    5

# %% [markdown]
# Ahora tenemos una nueva columna llamada “mes” que contiene un simple entero que representa el número del mes en cuestión. Ahora, utilizaremos funciones específicas de datetime de pandas. Nos apalancaremos de las capacidades de pandas y numpy para manipular datos de manera vectorizada:

# %%
datos_long['fecha'] = pd.to_datetime(
  datos_long['anio'].astype(str) + datos_long['mes'].astype(str),
  format='%Y%m'
)
datos_long.sample(5)
# Out:
#         anio  clave_ent           entidad  \
# 74666   2019         28        Tamaulipas
# 96044   2021          9  Ciudad de México
# 37474   2017         15            México
# 132192  2023         20            Oaxaca
# 27713   2016         26            Sonora
#
#                                            tipo_de_delito nombre_mes  \
# 74666                                            Lesiones  diciembre
# 96044                                        Acoso sexual       mayo
# 37474                                        Abuso sexual    octubre
# 132192                                        Feminicidio      abril
# 27713   Otros delitos que atentan contra la libertad y...      julio
#
#         frecuencia  mes      fecha
# 74666        248.0   12 2019-12-01
# 96044        120.0    5 2021-05-01
# 37474        166.0   10 2017-10-01
# 132192         2.0    4 2023-04-01
# 27713         12.0    7 2016-07-01

# %% [markdown]
# Ahora que tenemos una columna de tipo de dato datetime, podemos hacer filtros de fechas mucho más fácilmente:

# %%
datos_long[
    (datos_long.tipo_de_delito == "Homicidio") &
    (datos_long.clave_ent == 20) &
    (datos_long.fecha >= '2024-01-01')
].sort_values('fecha')
# Out:
#         anio  clave_ent entidad tipo_de_delito  nombre_mes  frecuencia  mes  \
# 147579  2024         20  Oaxaca      Homicidio       enero       154.0    1
# 147580  2024         20  Oaxaca      Homicidio     febrero       166.0    2
# 147583  2024         20  Oaxaca      Homicidio       marzo       184.0    3
# 147576  2024         20  Oaxaca      Homicidio       abril       200.0    4
# 147584  2024         20  Oaxaca      Homicidio        mayo       223.0    5
# 147582  2024         20  Oaxaca      Homicidio       junio       195.0    6
# 147581  2024         20  Oaxaca      Homicidio       julio       201.0    7
# 147577  2024         20  Oaxaca      Homicidio      agosto       186.0    8
# 147587  2024         20  Oaxaca      Homicidio  septiembre       190.0    9
# 147586  2024         20  Oaxaca      Homicidio     octubre       185.0   10
# 147585  2024         20  Oaxaca      Homicidio   noviembre       168.0   11
# 147578  2024         20  Oaxaca      Homicidio   diciembre       151.0   12
# 162939  2025         20  Oaxaca      Homicidio       enero       170.0    1
# 162940  2025         20  Oaxaca      Homicidio     febrero       141.0    2
# 162943  2025         20  Oaxaca      Homicidio       marzo       193.0    3
# 162936  2025         20  Oaxaca      Homicidio       abril       185.0    4
# 162944  2025         20  Oaxaca      Homicidio        mayo       172.0    5
# 162942  2025         20  Oaxaca      Homicidio       junio       132.0    6
# 162941  2025         20  Oaxaca      Homicidio       julio       159.0    7
# 162937  2025         20  Oaxaca      Homicidio      agosto       106.0    8
# 162947  2025         20  Oaxaca      Homicidio  septiembre        96.0    9
# 162946  2025         20  Oaxaca      Homicidio     octubre        85.0   10
# 162945  2025         20  Oaxaca      Homicidio   noviembre        88.0   11
# 162938  2025         20  Oaxaca      Homicidio   diciembre         0.0   12
#
#             fecha
# 147579 2024-01-01
# 147580 2024-02-01
# 147583 2024-03-01
# 147576 2024-04-01
# 147584 2024-05-01
# 147582 2024-06-01
# 147581 2024-07-01
# 147577 2024-08-01
# 147587 2024-09-01
# 147586 2024-10-01
# 147585 2024-11-01
# 147578 2024-12-01
# 162939 2025-01-01
# 162940 2025-02-01
# 162943 2025-03-01
# 162936 2025-04-01
# 162944 2025-05-01
# 162942 2025-06-01
# 162941 2025-07-01
# 162937 2025-08-01
# 162947 2025-09-01
# 162946 2025-10-01
# 162945 2025-11-01
# 162938 2025-12-01

# %% [markdown]
# - Obtuvimos muy fácilmente todos los homicidios en Oaxaca desde enero 2024 a la fecha.
#
# Ya que tenemos muestros datos bien estructurados, los podemos guardar en nuestra computadora. Los guardaremos con el nombre "delitos.csv" en la carpeta “data”.
#
# Estos los utilizaremos más adelante, entonces asegúrate de guardarlos.

# %%
datos_finales.to_csv('data/delitos.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 datos_finales.to_csv('data/delitos.csv', index=False)
#
# NameError: name 'datos_finales' is not defined

# %%
datos_finales = datos_long
datos_finales.to_csv('data/delitos.csv', index=False)
