# %%
import pandas as pd

edades = {
    'Liz' : [36],
    'Cloee' : [30]
}

tabla_de_edades = pd.DataFrame(edades)

tabla_de_edades
# Out:
#    Liz  Cloee
# 0   36     30

# %%
tabla_de_edades['Liz']
# Out:
# 0    36
# Name: Liz, dtype: int64

# %%
list(tabla_de_edades.Liz)
# Out:
# [36]

# %%
tabla_de_edades.Cloee
# Out:
# 0    30
# Name: Cloee, dtype: int64
